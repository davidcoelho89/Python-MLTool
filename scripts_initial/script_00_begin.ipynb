# %% [markdown]
# # Bem-vindo ao Python!
#
# Este é um resumo inicial para aprender a programar!
#
# ** Python para Data Science e Machine Learning **
#
# Verificar a toolbox: [Machine Learning] (https://github.com/davidcoelho89/MLTool_python).
#
# ## Visão geral deste Conteúdo
#
# Este notebook contém algumas informações iniciais e links.

# %% [markdown]
# # Comandos e Atalhos iniciais:
#
# -> "escreve algo" + tab => dá dica de como completar
#
# -> "escreve função" + shift + tab => mostra assinatura da função
#
# -> Comentario de uma linha: # Comment
#
# -> Comentario multilinhas: ''' comment ''' (não é recomendavel)
#
# -> Jupyter: alt + enter (cria nova celula abaixo)
#
# -> Jupyter: shift + enter (gera output da celula)

# %%
# Links Gerais

'''
- Documentation
https://wiki.python.org.br/DocumentacaoPython

- Porque python?
http://www.stat.washington.edu/~hoytak/blog/whypython.html

- Python for Embedded
https://www.zerynth.com/blog/the-rise-of-python-for-embedded-systems/

- The best way to learn python
https://www.youtube.com/watch?v=NwyIuWK80gQ&list=PLwNU7Gk6Z5ZkXXsvtJTtBhQNl905Jua-O

- Principios de Programação com Python
https://www.youtube.com/watch?v=-x-Le_podxo&list=PL51430F6C54953B73

- Migrar de Matlab para Python
http://leportella.com/pt-br/2017/05/06/10-dicas-matlab-para-python.html

- Bitwise Operations
https://wiki.python.org/moin/BitwiseOperators

- Python Summary (45 min)
https://www.youtube.com/watch?v=N4mEzFDjqtA

- Programação "mais limpa" em python:
https://www.youtube.com/watch?v=OSGv2VnC0go&feature=youtu.be

- Data Visualization
https://www.youtube.com/watch?v=OC-YdBz8Llw

- Installing Anaconda
https://www.youtube.com/watch?v=YJC6ldI3hWk

- Conda
https://www.youtube.com/watch?v=FgfKA-HJFI0
https://www.youtube.com/watch?v=HSK-6dCnYVQ
https://www.youtube.com/watch?v=lWP2MCT8qhw

- Kaggle: site com datasets para Data Science e Machine Learning
https://www.kaggle.com

-> Pessoas com dinheiro, investem em pessoas/ideias que precisam de dinheiro
- https://www.lendingclub.com/ LendingClub.com
'''

# %%
# Conhecimentos Iniciais

'''
=> Linguagem: Python

- Linguagem de programação interpretada

=> Linguagem: Outras

- R, Matlab, Julia, Octave

=> Gerenciador de Pacotes: Anaconda

- http://docs.anaconda.org
- Bom para não precisar ficar lidando com atualizações
- Navegador mostra todos os aplicativos python instalados

=> Deal with Documents: Jupyter (Python, Julia, R, C++)

- Facilita a transferência de dados, programação...
- Serve também como IDE
- Pode acessar por try.jupyter.org
- Bom para tutoriais e prototipação de códigos

=> IDEs: 

- Spyder:  Mais leve, gratuita. Para testes e fins academicos
- Pycharm: suporte maior para desenvolvimento de software. Pago.
- VS Code: Visual Studio Code -> possui suporte para python
- Eclipse: Android Studio -> 
- Atom.Io: 
- Sublime: 

- Modifica todas as variaveis (ctrl + shift + f / ctrl + f)
- Não precisam de 'clear' e 'clc' => ao executar, já zera variáveis

=> Console:

- iPython: interpretador interativo. Pode substituir o "shell"

=> FERRAMENTAS / APIs

- AutoML:      Automatizam a escolha de parâmetros
- BigML:       Executado no navegador.
- DataRobot:   Se conecta a fonte de dados, possui libs, pode ser implantado em nuvem local
- H2O:         Junta várias soluções de aprendizado de máquina
- Keras:       Open-source neural-network library written in Python
- OpenCv:      Lida com 
- RapidMiner:  Produzir vários modelos e depois identificar o melhor
- R Studio:    Software livre para programar em R
- Splunk:      Analise de dados
- TensorFlow:  Biblioteca de software de código aberto para computação numérica 
- TensorBoard: Para visualização de dados
'''

# %%
# Bibliotecas - Libraries

'''
- Também chamadas "packages" ou "modulos"
- Modulo é um conjunto de códigos fonte.
- Pode ser constituido de: instruções, classes, funções e variáveis
- Módulos podem usar outros módulos
- Link: https://bigdata-madesimple.com/top-20-python-libraries-for-data-science/

Cython        Compile python into c extensions    http://cython.org
Dask          Parallelism for analytics           https://dask.org/     
Drawnow       Plots iterativos                    https://pypi.org/project/drawnow/
Intel Dist    Accelerate and scale app            https://software.intel.com/en-us/distribution-for-python
Kivy          Python on mobile devices            https://kivy.org/doc/stable/
MatplotLib    Graficos gerais                     http://matplotlib.org
MlPy          Predictive modeling                 http://mlpy.sourceforge.net
Numba         Python to optimized machine code    https://numba.pydata.org/    
NumPy         Operacoes com matrizes (CPU)        http://www.numpy.org
NlTk          Natural Language Processing         http://www.nltk.org 
Octave Kernel Octave compiling for python         https://pypi.org/project/octave-kernel/
Pandas        Analise de dados                    http://pandas.pydata.org
Plotly        Plots iterativos                    https://plot.ly/python/
PyGame        Animações                           https://www.pygame.org/docs/
PyRobotics    Experiments in robot learning       http://pyrorobotics.com
PySerial      Serial with Raspi                   https://pyserial.readthedocs.io/en/latest/
PySide        QT for Python                       https://srinikom.github.io/pyside-docs/
PySpark       Exploratory data analysis           https://spark.apache.org/docs/0.9.0/python-programming-guide.html
PyTorch       GPU to solve numerical problems     https://pytorch.org/docs/stable/index.html
Seaborn       Graficos estatisticos               https://seaborn.pydata.org/
Scikit Learn  Analise de dados                    http://scikit-learn.org
Scikit Image  Visualizacao de dados               http://scikit-image.org
SciPy         Inteligencia Artificial             http://www.scipy.org
StatsModels   Statistical Tests and Estimation    https://www.statsmodels.org/stable/index.html        
SymPy         For symbolic mathematics            http://sympy.org/en/index.html
Swifter       Automatically efficient pandas      https://lnkd.in/gFK285E      
Tkinter       Python GUI / Interface              https://docs.python.org/3/library/tkinter.html
'''

# %%
# Duvidas e Solucoes

'''
-> Pipelines: sequencia de codigos para ser executados

-> Metodos e atributos com a mesma assinatura do SciKit Learn!

-> Inversão (batch): inv() => pinv() (svd)

-> Inicializa: np.eye() / np.zeros()

-> Produto escalar:  np.inner() (transpoe) / np.dot() nao transpoe

-> Produto vetorial: np.outer()

-> bubble_sort(): fazer função! [7,2,5,8] -> [2,5,7,8]

-> Python Plot (plotly x matplotlib)
- plt.figure() / plt.plot(x , marker = '.') / plt.title()
- Salvar imagens: pdf ou eps

-> Outras Libs
- Weka (java) / MGV / Polaris / Samoa / 

-> Automação de Rotinas
- DATA, MODEL, HP, SEED

-> Leitura e Gravação de vários objetos
- Scipy: verificar se faz isso!!

-> Online Algorithms
- Verificar se metodo "fit()" já atualiza automaticamente os parâmetros
  (se já chamou o método "fit()" uma vez, se chamar novamente, ele usa os parâmetros já atualizados?)
- Caso contrário, fazer o método update().

-> Cross Validation
- Ja fazer automaticamente! Facilita desenvolvimento!

-> GUI Python
- Pesquisar se já existe "scikit gui"
- Tkinter x Web => verificar padrões para implementar.

'''
